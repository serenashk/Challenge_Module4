# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
#Create a path to the "whale_returns" file
csvpath_whale = Path("Resources/whale_returns.csv")

# Reading whale returns CSV into a DataFrame, converting date strings into datetime objects and setting the datetime as the index
whale_df = pd.read_csv(csvpath_whale, index_col = 'Date', parse_dates = True, infer_datetime_format=True)

# Take sample of data
whale_df.sample(10)
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\3440980688.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df = pd.read_csv(csvpath_whale, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-31                  -0.005445           -0.003021
# 2018-07-06                   0.012643            0.009595
# 2015-06-17                  -0.001715           -0.002333
# 2017-05-19                   0.005603            0.003113
# 2018-12-20                  -0.016673           -0.008347
# 2017-06-26                   0.000854            0.001480
# 2015-09-16                   0.010404            0.003123
# 2017-02-23                  -0.006354            0.002178
# ...

# %%
# Sort DataFrame in ascending order
whale_df.sort_index(ascending = True, inplace = True)

# Show the first values of the DataFrame
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()

# Confirm the dropping of nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
#Create a path to the file
csvpath_algo = Path("Resources/algo_returns.csv")

# Reading algorithmic returns CSV into a DataFrame using Pandas, converting date strings into datetime objects and setting the datetime as the index
algo_df = pd.read_csv(csvpath_algo, index_col = 'Date', parse_dates = True, infer_datetime_format=True)

# Take sample of data
algo_df.sample(5)
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\371006396.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df = pd.read_csv(csvpath_algo, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
#               Algo 1    Algo 2
# Date
# 2016-05-09  0.009159 -0.006076
# 2017-07-03 -0.007349  0.007059
# 2017-06-20  0.001791 -0.006520
# 2017-12-11  0.001439  0.000244
# 2014-12-02 -0.005083  0.008600

# %%
# Sort DataFrame in ascending order
algo_df.sort_index(ascending = True, inplace = True)

# Show the first values of the DataFrame
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()

# Confirm the dropping of nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
#Create a path to the file
csvpath_sp500 = Path("Resources/sp500_history.csv")

# Reading S&P 500 Closing Prices into a DataFrame using Pandas, converting date strings into datetime objects and setting the datetime as the index
sp500_df = pd.read_csv(csvpath_sp500, index_col='Date', parse_dates=True, infer_datetime_format=True, date_parser=lambda x: pd.to_datetime(x, format='%d-%b-%y'))

# Show the first rows of DataFrame to identify if numeric field with '$' symbol
sp500_df.head()
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\1760646783.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df = pd.read_csv(csvpath_sp500, index_col='Date', parse_dates=True, infer_datetime_format=True, date_parser=lambda x: pd.to_datetime(x, format='%d-%b-%y'))
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\1760646783.py:5: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   sp500_df = pd.read_csv(csvpath_sp500, index_col='Date', parse_dates=True, infer_datetime_format=True, date_parser=lambda x: pd.to_datetime(x, format='%d-%b-%y'))
#                Close
# Date
# 2019-04-23  $2933.68
# ...

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Clean identified numeric fields with $ symbol
sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")

# Show the first values of the DataFrame
sp500_df.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Retrieve data types to confirm what needs to be converted
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types by converting 'Close' from 'object' to 'float'
sp500_df["Close"] = sp500_df["Close"].astype("float")

# Confirm conversion worked as expected
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Sort DataFrame in ascending order to ensure the correct Daily Returns calculation
sp500_df.sort_index(ascending = True, inplace = True)

# Show the first values of the DataFrame
sp500_df.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns
daily_returns_sp500 = sp500_df.pct_change()

# Show the first values of the DataFrame
daily_returns_sp500.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
daily_returns_sp500 = daily_returns_sp500.dropna()

# Show the first values of the DataFrame
daily_returns_sp500.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
daily_returns_sp500 = daily_returns_sp500.rename(columns={"Close":"S&P_Return"})

# Show the first rows of DataFrame
daily_returns_sp500.head()
# Out:
#             S&P_Return
# Date
# 2012-10-02    0.000872
# 2012-10-03    0.003624
# 2012-10-04    0.007174
# 2012-10-05   -0.000322
# 2012-10-08   -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
all_portfolios_returns = pd.concat([whale_df, algo_df, daily_returns_sp500], axis = 1, join ='inner')

# Show the first values of the combined DataFrame
all_portfolios_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P_Return
# Date
# 2015-03-03 -0.000949   -0.004539
# 2015-03-04  0.002416   -0.004389
# 2015-03-05  0.004323    0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_portfolios_returns.plot(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + all_portfolios_returns).cumprod()

# Show the first rows of 'comulative_returns' DataFrame
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2  S&P_Return
# Date
# 2015-03-03  0.999051    0.995461
# 2015-03-04  1.001464    0.991093
# 2015-03-05  1.005794    0.992278
# ...

# %%
# Plot cumulative returns of all portfolios
cumulative_returns.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Does any portfolio outperform the S&P 500?
# From the plot of cumulative returns of all portfolios, I can notice that Algo 1 outperforms S&P 500. But also in particular periods of time, TIGER GLOBAL MANAGEMENT LLC has noticeably higher cumulative returns than S&P 500 and also in particular periods of time BERKSHIRE HATHAWAY INC has noticeably higher cumulative returns than S&P 500.

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Create a box plot for daily returns of all portfolios
all_portfolios_returns.plot.box(figsize = (18,5))
# Out:
# <Axes: >

# %%
# Create a box plot for cumulative returns of all portfolios
cumulative_returns.plot.box(figsize=(18,5))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of each portfolio
all_portfolio_std = all_portfolios_returns.std()
all_portfolio_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P_Return                     0.008554
# dtype: float64

# %%
# Convert the Series to a DataFrame with a single column
daily_st_deviation_df = pd.DataFrame(all_portfolio_std, columns = ['Daily Std Deviation']).T

# Display the first 7 rows of the DataFrame
print(daily_st_deviation_df.head(7))
# Out:
#                      SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Daily Std Deviation                   0.007895            0.007023
#
#                      TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  \
# Daily Std Deviation                     0.010894                0.012919
#
#                       Algo 1    Algo 2  S&P_Return
# Daily Std Deviation  0.00762  0.008342    0.008554

# %%
# Box plot to visually show risk
daily_st_deviation_df.plot.box(figsize=(18,5))
# Out:
# <Axes: >

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_sd_sp500 = daily_returns_sp500.std()
daily_sd_sp500
# Out:
# S&P_Return    0.008111
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
all_portfolio_std.sort_values(ascending = False)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P_Return                     0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ## Determine which portfolios are riskier than the S&P 500?
# After sorting the values of standard deviations of each portfolio in descending order, I can conclude that the portfolios riskier than the S&P 500 are BERKSHIRE HATHAWAY INC and TIGER GLOBAL MANAGEMENT LLC.

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
all_annual_sd = all_portfolio_std*np.sqrt(252)

# Sort values in descending order to compare the risk between portfolios and display the DataFrame
all_annual_sd.sort_values(ascending = False)
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P_Return                     0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_std_all = all_portfolios_returns.rolling(window = 21).std()
rolling_std_all.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN     NaN
# 2015-03-04                          NaN                     NaN     NaN
# 2015-03-05                          NaN                     NaN     NaN
# 2015-03-06                          NaN                     NaN     NaN
# 2015-03-09                          NaN                     NaN     NaN
#
#             Algo 2  S&P_Return
# Date
# 2015-03-03     NaN         NaN
# 2015-03-04     NaN         NaN
# 2015-03-05     NaN         NaN
# 2015-03-06     NaN         NaN
# ...

# %%
rolling_std_all = rolling_std_all.dropna()
rolling_std_all
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-31                   0.005764            0.004641
# 2015-04-01                   0.005744            0.004467
# 2015-04-02                   0.005749            0.004502
# 2015-04-06                   0.005792            0.004492
# 2015-04-07                   0.005452            0.004385
# ...                               ...                 ...
# 2019-04-16                   0.006711            0.006224
# 2019-04-17                   0.006773            0.006370
# 2019-04-18                   0.006633            0.006303
# 2019-04-22                   0.005915            0.006400
# 2019-04-23                   0.004315            0.005695
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-31                     0.006731                0.007108  0.007866
# 2015-04-01                     0.006750                0.007005  0.007886
# ...

# %%
# Plot the rolling standard deviation
rolling_std_all.plot(figsize = (15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_matrix = all_portfolios_returns.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P_Return                                    0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Plot the correlation between each stock to determine which portfolios may mimic the S&P 500
sns.heatmap(correlation_matrix, vmin = -1, vmax = 1, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Determine which portfolios may mimic the S&P 500?
# From the plot above I can conclude that the porfolios which may mimic S&P 500 are Algo 2 and Soros Fund Management LLC because these portfolios have higher correlation values with the S&P 500 compared to the other portfolios.

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of SOROS FUND MANAGEMENT LLC vs. S&P 500
covariance = all_portfolios_returns.iloc[:,0].cov(all_portfolios_returns.iloc[:,6])
# Display covariance
covariance
# Out:
# 5.658503197203613e-05

# %%
# Calculate variance of S&P 500
variance = all_portfolios_returns.iloc[:,6].var()
# Display variance of S&P 500
variance
# Out:
# 7.316632424648712e-05

# %%
# Computing beta
soros_beta = covariance / variance
# Display beta for SOROS FUND MANAGEMENT LLC
soros_beta
# Out:
# 0.7733753547794621

# %%
# Calculate 60-day rolling covariance of SOROS FUND MANAGEMENT LLC vs. S&P 500
rolling_covariance = all_portfolios_returns.iloc[:,0].rolling(window=60).cov(all_portfolios_returns.iloc[:,6])
# Calculate 60-day rolling variance of SOROS FUND MANAGEMENT LLC vs. S&P 500 and plot the data
rolling_variance = all_portfolios_returns.iloc[:,6].rolling(window=60).var()
# Calculate 60-day rolling beta of SOROS FUND MANAGEMENT LLC and plot the data
rolling_beta = rolling_covariance / rolling_variance
# Show rolling_beta values of the DataFrame
rolling_beta
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.840772
# 2019-04-17    0.822868
# 2019-04-18    0.823598
# 2019-04-22    0.825137
# 2019-04-23    0.806330
# Length: 1043, dtype: float64

# %%
# Drop null values from 'rolling_beta' DataFrame
rolling_beta.dropna()
# Out:
# Date
# 2015-05-27    0.587678
# 2015-05-28    0.589662
# 2015-05-29    0.592375
# 2015-06-01    0.591645
# 2015-06-02    0.590608
#                 ...
# 2019-04-16    0.840772
# 2019-04-17    0.822868
# 2019-04-18    0.823598
# 2019-04-22    0.825137
# 2019-04-23    0.806330
# Length: 984, dtype: float64

# %%
# Plot the 60-day beta trend between SOROS FUND MANAGEMENT LLC and the S&P 500.
rolling_beta.plot(figsize=(20, 10), title ='Rolling 60-Day Beta of SOROS FUND MANAGEMENT LLC')
# Out:
# <Axes: title={'center': 'Rolling 60-Day Beta of SOROS FUND MANAGEMENT LLC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Calculate EWMA of returns for the stock and the market index
ewma_stock_returns = all_portfolios_returns.iloc[:,0].ewm(halflife=21).mean()
ewma_market_returns = all_portfolios_returns.iloc[:,6].ewm(halflife=21).mean()

# Calculate the covariance between the EWMA returns of the stock and the market index for a rolling window of 60 days
cov_ewma_rolling = ewma_stock_returns.rolling(window=60).cov(ewma_market_returns)

# Calculate the variance of the EWMA returns of the market index for a rolling window of 60 days
var_ewma_rolling = ewma_market_returns.rolling(window=60).var()

# Calculate beta using EWMA
beta_ewma = cov_ewma_rolling / var_ewma_rolling

# Print beta calculated using EWMA for a rolling window of 60 days
print(beta_ewma)
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.694775
# 2019-04-17    0.664002
# 2019-04-18    0.616569
# 2019-04-22    0.578285
# 2019-04-23    0.568640
# Length: 1043, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate annualized Sharpe Ratios for each individual portfolio using the daily returns
sharpe_ratios = (all_portfolios_returns.mean() * 252) / (all_portfolios_returns.std() * np.sqrt(252))
# Display Sharpe Ratios DataFrame
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P_Return                     0.648267
# dtype: float64

# %%
# Sort sharpe_ratios DataFrame in descending order to determine successful portfolios
sharpe_ratios.sort_values(ascending = False)
# Out:
# Algo 1                         1.378648
# S&P_Return                     0.648267
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 2                         0.501364
# SOROS FUND MANAGEMENT LLC      0.356417
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# PAULSON & CO.INC.             -0.483570
# dtype: float64

# %%
# Visualize the sharpe ratios using a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Based off of risk to reward ratio, only one algorithmic portfolio, which is 'Algo 1', outperforms both the market and the whales portofolios. This algorithmic portfolio is getting more return for one unit of standard deviation than the other portfolios. In order to determine successful portfolios I have calculated annualized Sharpe Ratios for each individual portfolio and I sorted 'sharpe_ratios' DataFrame in descending order. The other algorithmic portfolio, which is 'Algo 2', is below market and below one of the whale portfolios, but above other remaining whale portfolios. I can conclude that 'Algo 2' is moderately successful based off of risk to reward ratio. I can conclude that the algorithmic strategies are successful and outperform both the market (S&P 500) and the whales portfolios.
# 'Algo 1'

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
#Create a path to the "meta_historical" file that is about 1 year's worth of historic prices of 'META' stock
csvpath_meta = Path("meta_historical.csv")

# Reading data from 1st stock into a DataFrame, converting date strings into datetime objects and setting the datetime as the index
meta_df = pd.read_csv(csvpath_meta, index_col = 'Date', parse_dates = True, infer_datetime_format=True)

# Show the first 10 values of DataFrame
meta_df.head(10)
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\3041566228.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   meta_df = pd.read_csv(csvpath_meta, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\3041566228.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   meta_df = pd.read_csv(csvpath_meta, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
#              Close
# Date
# 2023-03-01  124.74
# 2023-04-01  127.37
# 2023-05-01  126.94
# 2023-06-01  130.02
# 2023-09-01  129.47
# 2023-10-01  132.99
# 2023-11-01  132.89
# ...

# %%
#Create a path to the "amzn_historical" file that is about 1 year's worth of historic prices of 'AMAZON' stock
csvpath_amzn = Path("amzn_historical.csv")

# Reading data from 2nd stock into a DataFrame, converting date strings into datetime objects and setting the datetime as the index
amzn_df = pd.read_csv(csvpath_amzn, index_col = 'Date', parse_dates = True, infer_datetime_format=True)

# Show the first values of DataFrame
amzn_df.head()
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\485613972.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   amzn_df = pd.read_csv(csvpath_amzn, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\485613972.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   amzn_df = pd.read_csv(csvpath_amzn, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
#             Close
# Date
# 2023-03-01  85.82
# 2023-04-01  85.14
# 2023-05-01  83.12
# 2023-06-01  86.08
# 2023-09-01  87.36

# %%
#Create a path to the "amzn_historical" file that is about 1 year's worth of historic prices of 'MICROSOFT CORP' stock
csvpath_msft = Path("msft_historical.csv")

# Reading data from 3rd stock into a DataFrame, converting date strings into datetime objects and setting the datetime as the index
msft_df = pd.read_csv(csvpath_msft, index_col = 'Date', parse_dates = True, infer_datetime_format=True)

# Show the first values of DataFrame
msft_df.head()
# Out:
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\3153014615.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   msft_df = pd.read_csv(csvpath_msft, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
# C:\Users\GERMAN PC\AppData\Local\Temp\ipykernel_9664\3153014615.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   msft_df = pd.read_csv(csvpath_msft, index_col = 'Date', parse_dates = True, infer_datetime_format=True)
#              Close
# Date
# 2023-03-01  239.58
# 2023-04-01  229.10
# 2023-05-01  222.31
# 2023-06-01  224.93
# 2023-09-01  227.12

# %%
# Combine all stocks in a single DataFrame with columns for each portfolio's returns
my_portfolio = pd.concat([meta_df, amzn_df, msft_df], axis = 1, join ='inner')

# Show the first values of the combined DataFrame
my_portfolio.head()
# Out:
#              Close  Close   Close
# Date
# 2023-03-01  124.74  85.82  239.58
# 2023-04-01  127.37  85.14  229.10
# 2023-05-01  126.94  83.12  222.31
# 2023-06-01  130.02  86.08  224.93
# 2023-09-01  129.47  87.36  227.12

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns

# Drop NAs

# Display sample data

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
